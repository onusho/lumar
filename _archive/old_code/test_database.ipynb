# %%
import weaviate
from weaviate.classes.config import Configure, Multi2VecField
from weaviate.classes.query import Filter

# %%
# Multi2VecField?

# %%
client = weaviate.connect_to_local()

# %%
if client.collections.exists('ClipCollection'):
        # collection = client.collections.get('ClipCollection')
        client.collections.delete('ClipCollection')
# else:
collection = client.collections.create(
    name="ClipCollection",
    vectorizer_config=Configure.Vectorizer.multi2vec_clip(
            image_fields=[
                Multi2VecField(
                        name="image"
                )
            ],
            text_fields=[
                Multi2VecField(
                        name="text"
                ),
                Multi2VecField(
                        name="media_type"
                )
            ]
    ),
#     generative_config=Configure.Generative.ollama(
#         api_endpoint="http://host.docker.internal:11434",
#         model="llama3.1"
#     )
)

# %%
from data_loader import DataLoader

folder_path = r"C:\Users\swast\OneDrive\Desktop\runSwastik\Localinsight\documents"
loader = DataLoader(folder_path)
# Out:
# c:\Users\swast\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:7: DeprecationWarning: 'aifc' is deprecated and slated for removal in Python 3.13
#   import aifc
# c:\Users\swast\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:8: DeprecationWarning: 'audioop' is deprecated and slated for removal in Python 3.13
#   import audioop

# %%
object_list = loader.load_data()

# %%
object_list
# Out:
# [{'chunk_no': 0,
#   'text': 'Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 1,
#   'text': 'her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 2,
#   'text': 'So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 3,
#   'text': 'daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 4,
#   'text': 'There was nothing so very remarkable in that; nor did Alice think it so very much out of the way to hear the Rabbit say to itself, “Oh dear! Oh dear! I shall be late!” (when she thought it over',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 5,
#   'text': 'dear! I shall be late!” (when she thought it over afterwards, it occurred to her that she ought to have wondered at this, but at the time it all seemed quite natural); but when the Rabbit actually',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 6,
#   'text': 'quite natural); but when the Rabbit actually took a watch out of its waistcoat-pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 7,
#   'text': 'feet, for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket, or a watch to take out of it, and burning with curiosity, she ran across the field after',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 8,
#   'text': 'with curiosity, she ran across the field after it, and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 9,
#   'text': 'In another moment down went Alice after it, never once considering how in the world she was to get out again.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 10,
#   'text': 'The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 11,
#   'text': 'stopping herself before she found herself falling down a very deep well.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 12,
#   'text': 'Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next. First, she tried to look down and',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 13,
#   'text': 'to happen next. First, she tried to look down and make out what she was coming to, but it was too dark to see anything; then she looked at the sides of the well, and noticed that they were filled',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 14,
#   'text': 'of the well, and noticed that they were filled with cupboards and book-shelves; here and there she saw maps and pictures hung upon pegs. She took down a jar from one of the shelves as she passed; it',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 15,
#   'text': 'a jar from one of the shelves as she passed; it was labelled “ORANGE MARMALADE”, but to her great disappointment it was empty: she did not like to drop the jar for fear of killing somebody',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 16,
#   'text': 'like to drop the jar for fear of killing somebody underneath, so managed to put it into one of the cupboards as she fell past it.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 17,
#   'text': '“Well!” thought Alice to herself, “after such a fall as this, I shall think nothing of tumbling down stairs! How brave they’ll all think me at home! Why, I wouldn’t say anything about it, even if I',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 18,
#   'text': 'Why, I wouldn’t say anything about it, even if I fell off the top of the house!” (Which was very likely true.)',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 19,
#   'text': 'Down, down, down. Would the fall never come to an end? “I wonder how many miles I’ve fallen by this time?” she said aloud. “I must be getting somewhere near the centre of the earth. Let me see: that',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 20,
#   'text': 'near the centre of the earth. Let me see: that would be four thousand miles down, I think—” (for, you see, Alice had learnt several things of this sort in her lessons in the schoolroom, and though',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 21,
#   'text': 'sort in her lessons in the schoolroom, and though this was not a very good opportunity for showing off her knowledge, as there was no one to listen to her, still it was good practice to say it over)',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 22,
#   'text': 'her, still it was good practice to say it over) “—yes, that’s about the right distance—but then I wonder what Latitude or Longitude I’ve got to?” (Alice had no idea what Latitude was, or Longitude',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 23,
#   'text': 'had no idea what Latitude was, or Longitude either, but thought they were nice grand words to say.)',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 24,
#   'text': 'Presently she began again. “I wonder if I shall fall right through the earth! How funny it’ll seem to come out among the people that walk with their heads downward! The Antipathies, I think—” (she',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 25,
#   'text': 'heads downward! The Antipathies, I think—” (she was rather glad there was no one listening, this time, as it didn’t sound at all the right word) “—but I shall have to ask them what the name of the',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 26,
#   'text': 'I shall have to ask them what the name of the country is, you know. Please, Ma’am, is this New Zealand or Australia?” (and she tried to curtsey as she spoke—fancy curtseying as you’re falling through',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 27,
#   'text': 'spoke—fancy curtseying as you’re falling through the air! Do you think you could manage it?) “And what an ignorant little girl she’ll think me for asking! No, it’ll never do to ask: perhaps I shall',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 28,
#   'text': 'No, it’ll never do to ask: perhaps I shall see it written up somewhere.”',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 29,
#   'text': 'Down, down, down. There was nothing else to do, so Alice soon began talking again. “Dinah’ll miss me very much to-night, I should think!” (Dinah was the cat.) “I hope they’ll remember her saucer of',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 30,
#   'text': 'the cat.) “I hope they’ll remember her saucer of milk at tea-time. Dinah my dear! I wish you were down here with me! There are no mice in the air, I’m afraid, but you might catch a bat, and that’s',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 31,
#   'text': 'I’m afraid, but you might catch a bat, and that’s very like a mouse, you know. But do cats eat bats, I wonder?” And here Alice began to get rather sleepy, and went on saying to herself, in a dreamy',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 32,
#   'text': 'and went on saying to herself, in a dreamy sort of way, “Do cats eat bats? Do cats eat bats?” and sometimes, “Do bats eat cats?” for, you see, as she couldn’t answer either question, it didn’t much',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 33,
#   'text': 'couldn’t answer either question, it didn’t much matter which way she put it. She felt that she was dozing off, and had just begun to dream that she was walking hand in hand with Dinah, and saying to',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 34,
#   'text': 'walking hand in hand with Dinah, and saying to her very earnestly, “Now, Dinah, tell me the truth: did you ever eat a bat?” when suddenly, thump! thump! down she came upon a heap of sticks and dry',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 35,
#   'text': 'down she came upon a heap of sticks and dry leaves, and the fall was over.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 36,
#   'text': 'Alice was not a bit hurt, and she jumped up on to her feet in a moment: she looked up, but it was all dark overhead; before her was another long passage, and the White Rabbit was still in sight,',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 37,
#   'text': 'passage, and the White Rabbit was still in sight, hurrying down it. There was not a moment to be lost: away went Alice like the wind, and was just in time to hear it say, as it turned a corner, “Oh',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 38,
#   'text': 'time to hear it say, as it turned a corner, “Oh my ears and whiskers, how late it’s getting!” She was close behind it when she turned the corner, but the Rabbit was no longer to be seen: she found',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 39,
#   'text': 'the Rabbit was no longer to be seen: she found herself in a long, low hall, which was lit up by a row of lamps hanging from the roof.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 40,
#   'text': 'There were doors all round the hall, but they were all locked; and when Alice had been all the way down one side and up the other, trying every door, she walked sadly down the middle, wondering how',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 41,
#   'text': 'she walked sadly down the middle, wondering how she was ever to get out again.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 42,
#   'text': 'Suddenly she came upon a little three-legged table, all made of solid glass; there was nothing on it except a tiny golden key, and Alice’s first thought was that it might belong to one of the doors',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 43,
#   'text': 'was that it might belong to one of the doors of the hall; but, alas! either the locks were too large, or the key was too small, but at any rate it would not open any of them. However, on the second',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 44,
#   'text': 'not open any of them. However, on the second time round, she came upon a low curtain she had not noticed before, and behind it was a little door about fifteen inches high: she tried the little golden',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 45,
#   'text': 'fifteen inches high: she tried the little golden key in the lock, and to her great delight it fitted!',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 46,
#   'text': 'Alice opened the door and found that it led into a small passage, not much larger than a rat-hole: she knelt down and looked along the passage into the loveliest garden you ever saw. How she longed',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 47,
#   'text': 'the loveliest garden you ever saw. How she longed to get out of that dark hall, and wander about among those beds of bright flowers and those cool fountains, but she could not even get her head',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 48,
#   'text': 'fountains, but she could not even get her head through the doorway; “and even if my head would go through,” thought poor Alice, “it would be of very little use without my shoulders. Oh, how I wish I',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 49,
#   'text': 'little use without my shoulders. Oh, how I wish I could shut up like a telescope! I think I could, if I only knew how to begin.” For, you see, so many out-of-the-way things had happened lately, that',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 50,
#   'text': 'out-of-the-way things had happened lately, that Alice had begun to think that very few things indeed were really impossible.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 51,
#   'text': 'There seemed to be no use in waiting by the little door, so she went back to the table, half hoping she might find another key on it, or at any rate a book of rules for shutting people up like',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 52,
#   'text': 'rate a book of rules for shutting people up like telescopes: this time she found a little bottle on it, (“which certainly was not here before,” said Alice,) and round the neck of the bottle was a',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 53,
#   'text': 'Alice,) and round the neck of the bottle was a paper label, with the words “DRINK ME,” beautifully printed on it in large letters.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 54,
#   'text': 'It was all very well to say “Drink me,” but the wise little Alice was not going to do that in a hurry. “No, I’ll look first,” she said, “and see whether it’s marked ‘poison’ or not”; for she had read',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 55,
#   'text': 'it’s marked ‘poison’ or not”; for she had read several nice little histories about children who had got burnt, and eaten up by wild beasts and other unpleasant things, all because they would not',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 56,
#   'text': 'unpleasant things, all because they would not remember the simple rules their friends had taught them: such as, that a red-hot poker will burn you if you hold it too long; and that if you cut your',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 57,
#   'text': 'if you hold it too long; and that if you cut your finger very deeply with a knife, it usually bleeds; and she had never forgotten that, if you drink much from a bottle marked “poison,” it is almost',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 58,
#   'text': 'much from a bottle marked “poison,” it is almost certain to disagree with you, sooner or later.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 59,
#   'text': 'However, this bottle was not marked “poison,” so Alice ventured to taste it, and finding it very nice, (it had, in fact, a sort of mixed flavour of cherry-tart, custard, pine-apple, roast turkey,',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'chunk_no': 60,
#   'text': 'cherry-tart, custard, pine-apple, roast turkey, toffee, and hot buttered toast,) she very soon finished it off.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\alice.txt',
#   'media_type': 'text'},
#  {'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cat2.jpg',
#   'media_type': 'image',
#   'image': '...'},
#  {'chunk_no': 0,
#   'text': "Here's a sample text about cats:\n\n---\n\n**The Enigmatic World of Cats**",
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 1,
#   'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As one of the most popular pets worldwide, they offer a unique blend of independence and affection. From',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 2,
#   'text': 'unique blend of independence and affection. From the domesticated house cats to the wild, majestic lions, cats belong to a family known as Felidae.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 3,
#   'text': 'Domesticated cats, or **Felis catus**, are known for their agility and grace. They have a natural curiosity that often leads them to explore every nook and cranny of their environment. Despite their',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 4,
#   'text': 'and cranny of their environment. Despite their reputation for being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat has its own personality; some are',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 5,
#   'text': 'Each cat has its own personality; some are playful and energetic, while others are calm and reserved.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 6,
#   'text': 'One of the most fascinating aspects of cats is their communication. Cats use a variety of vocalizations, body language, and even scent markings to convey their feelings. A purring cat often indicates',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 7,
#   'text': 'their feelings. A purring cat often indicates contentment, though it can also be a sign of nervousness or discomfort. Their tail movements, ear positions, and eye behavior provide further clues to',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 8,
#   'text': 'and eye behavior provide further clues to their mood.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 9,
#   'text': 'Cats are also skilled hunters, a trait inherited from their wild ancestors. Even the most pampered house cat might display hunting behavior, like stalking and pouncing on toys or insects. This',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 10,
#   'text': 'stalking and pouncing on toys or insects. This instinctual behavior is a reminder of their wild roots.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 11,
#   'text': 'In addition to their captivating behavior, cats have a rich history with humans. They were revered in ancient Egypt, where they were considered sacred and often depicted in art and statues. Today,',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 12,
#   'text': 'and often depicted in art and statues. Today, cats continue to play important roles in various cultures and households, offering companionship and, at times, a sense of mystery.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 13,
#   'text': "Whether you're a long-time cat lover or a newcomer to the feline world, there's always something new to discover about these intriguing creatures. Their independent yet loving nature, combined with",
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 14,
#   'text': 'independent yet loving nature, combined with their graceful movements and expressive personalities, make cats one of the most beloved animals on the planet.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'chunk_no': 15,
#   'text': '--- \n\nThis text offers a brief exploration of the fascinating world of cats, touching on their behavior, communication, and historical significance.',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\dog1.jpg',
#   'media_type': 'image',
#   'image': '...'},
#  {'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\meerkat1.jpg',
#   'media_type': 'image',
#   'image': '...'}]

# %%
# from IPython.display import Image, Audio, Video

# def display_media(item):
#     path = item["path"]

#     if(item["media_type"] == "image"):
#         display(Image(path))

# %%
# for object in object_list:
#     if object['media_type'] == 'image':
#         display(Image(object['path']))

# %%
with collection.batch.dynamic() as batch:
    for object in object_list:
        batch.add_object(
            properties=object
        )
# collection.data.insert_many(object_list[0])

# %%
# collection.generate.near_text?

# %%
response = collection.query.near_text(
    query="cat",
    limit=5
)

# %%
response.objects
# Out:
# [Object(uuid=_WeaviateUUIDInt('7ccf80a2-8033-4f39-9283-b8f25adaf58f'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As one of the most popular pets worldwide, they offer a unique blend of independence and affection. From', 'chunk_no': 1.0, 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('3ce8ee06-7c3a-4e3c-b659-1fb628cedb1c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'and cranny of their environment. Despite their reputation for being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat has its own personality; some are', 'media_type': 'text', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'image': None, 'chunk_no': 4.0}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('715b42aa-c120-44ee-bf8e-f2810f6295bf'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'In addition to their captivating behavior, cats have a rich history with humans. They were revered in ancient Egypt, where they were considered sacred and often depicted in art and statues. Today,', 'chunk_no': 11.0, 'image': None, 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('5367e67f-d6ff-4238-8f4f-b8b2f91a2bc8'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'and often depicted in art and statues. Today, cats continue to play important roles in various cultures and households, offering companionship and, at times, a sense of mystery.', 'media_type': 'text', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'image': None, 'chunk_no': 12.0}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('433566c7-efdb-43d5-8c96-f9525665fb27'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'independent yet loving nature, combined with their graceful movements and expressive personalities, make cats one of the most beloved animals on the planet.', 'chunk_no': 14.0, 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection')]

# %%
properties = [object.properties for object in response.objects]

# %%
properties
# Out:
# [{'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As one of the most popular pets worldwide, they offer a unique blend of independence and affection. From',
#   'chunk_no': 1.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'},
#  {'text': 'and cranny of their environment. Despite their reputation for being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat has its own personality; some are',
#   'media_type': 'text',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'chunk_no': 4.0},
#  {'text': 'In addition to their captivating behavior, cats have a rich history with humans. They were revered in ancient Egypt, where they were considered sacred and often depicted in art and statues. Today,',
#   'chunk_no': 11.0,
#   'image': None,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'media_type': 'text'},
#  {'text': 'and often depicted in art and statues. Today, cats continue to play important roles in various cultures and households, offering companionship and, at times, a sense of mystery.',
#   'media_type': 'text',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'chunk_no': 12.0},
#  {'text': 'independent yet loving nature, combined with their graceful movements and expressive personalities, make cats one of the most beloved animals on the planet.',
#   'chunk_no': 14.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'}]

# %%
def search_with_text(query : str):
    return collection.query.near_text(
        query=query,
        limit=10
    )

def display_response(response):
    for object in response.objects:
        if object.properties['media_type'] == "text":
            print(object.properties)
            print('-'*20)
        elif object.properties['media_type'] == "image":
            print(object.properties)
            display(Image(object.properties['path']))
            print('-'*20)

# %%
response = search_with_text(query="cat image")

# %%
display_response(response)
# Out:
# {'text': 'being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 8.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'movements and expressive personalities, make cats one of the most beloved animals on the planet.', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 26.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'In addition to their captivating behavior, cats have a rich history with humans. They were revered', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 19.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 1.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'depicted in art and statues. Today, cats continue to play important roles in various cultures and', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 21.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'One of the most fascinating aspects of cats is their communication. Cats use a variety of', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 11.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'their owners. Each cat has its own personality; some are playful and energetic, while others are', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 9.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'Domesticated cats, or **Felis catus**, are known for their agility and grace. They have a natural', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 5.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'Cats use a variety of vocalizations, body language, and even scent markings to convey their', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 12.0, 'image': None, 'media_type': 'text'}
# --------------------
# {'text': 'Cats are also skilled hunters, a trait inherited from their wild ancestors. Even the most pampered', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 16.0, 'image': None, 'media_type': 'text'}
# --------------------

# %%
import base64
def search_with_image(image_path):
    def to_base64(path):
        with open(path, 'rb') as file:
            return base64.b64encode(file.read()).decode('utf-8')
    return collection.query.near_image(
        near_image=to_base64(image_path),
        limit=5
    )

# %%
response = search_with_image(image_path=r"C:\Users\swast\OneDrive\Desktop\runSwastik\Localinsight\ignore\multimodal-workshop\2-multimodal\source\image\cat3.jpg")

# %%
display_response(response)
# Out:
# {'text': None, 'image': '...', 'chunk_index': None, 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cat2.jpg', 'media_type': 'image'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 display_response(response)
#
# Cell In[14], line 14, in display_response(response)
#      12 elif object.properties['media_type'] == "image":
#      13     print(object.properties)
# ---> 14     display(Image(object.properties['path']))
#      15     print('-'*20)
#
# NameError: name 'Image' is not defined

# %%
response = collection.query.near_text(
    query="cat",
    limit=5
)

# %%
response.objects
# Out:
# [Object(uuid=_WeaviateUUIDInt('dcd9e7db-917b-4c86-a521-e54947a2e0a8'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 8.0, 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('4b8b0d78-33a4-4cd0-96d1-04222cee6f4c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'nook and cranny of their environment. Despite their reputation for being aloof, cats can be', 'image': None, 'chunk_index': 7.0, 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('7c3c6ef9-a8ee-4d13-833f-3427f55cfeef'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'movements and expressive personalities, make cats one of the most beloved animals on the planet.', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 26.0, 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('5532bf4b-e093-47fa-84ad-ac37c9c3055c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'In addition to their captivating behavior, cats have a rich history with humans. They were revered', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 19.0, 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection'),
#  Object(uuid=_WeaviateUUIDInt('59d7f658-1e5a-4952-83dc-4ba2be7cd74f'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As', 'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt', 'chunk_index': 1.0, 'image': None, 'media_type': 'text'}, references=None, vector={}, collection='ClipCollection')]

# %%
import base64
def to_base64(path):
    with open(path, 'rb') as file:
        return base64.b64encode(file.read()).decode('utf-8')

# %%
response = collection.query.near_image(
    near_image=to_base64(r"C:\Users\swast\OneDrive\Desktop\runSwastik\Localinsight\ignore\multimodal-workshop\2-multimodal\source\image\cat1.jpg"),
    limit=5
)

# %%
display_media(response.objects[0].properties)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 display_media(response.objects[0].properties)
#
# NameError: name 'display_media' is not defined

# %%
import weaviate
from weaviate.classes.config import Configure, Multi2VecField
from weaviate.classes.query import Filter
from data_loader import DataLoader
from IPython.display import Image
import base64

class DatabaseClient:
    
    def __init__(self, folder_path):
        self.create_client()
        self.generate_collection()
        self.data_ingestion(folder_path)
   
    def create_client(self):
        self.client = weaviate.connect_to_local()

    def generate_collection(self):
        if self.client.collections.exists('ClipCollection'):
            # collection = self.client.collections.get('ClipCollection')
            # return
            self.client.collections.delete('ClipCollection')

        self.collection = self.client.collections.create(
            name="ClipCollection",
            vectorizer_config=Configure.Vectorizer.multi2vec_clip(
                    image_fields=[
                        Multi2VecField(
                                name="image"
                        )
                    ],
                    text_fields=[
                        Multi2VecField(
                                name="text"
                        )
                    ]
            )#,
            # generative_config=Configure.Generative.ollama(
            #     api_endpoint="http://host.docker.internal:11434",
            #     model="llama3.1"
            # )
        )
    
    def data_ingestion(self, folder_path):
        loader = DataLoader(folder_path)
        object_list = loader.load_data()
        with self.collection.batch.dynamic() as batch:
            for object in object_list:
                batch.add_object(
                    properties=object
                )
    
    def search_with_text(self, query : str):
        response =  self.collection.query.near_text(
            query=query,
            limit=5
        )
        return [object.properties for object in response.objects]

    def search_with_image(self, image_path):
        def to_base64(path):
            with open(path, 'rb') as file:
                return base64.b64encode(file.read()).decode('utf-8')
        response = self.collection.query.near_image(
            near_image=to_base64(image_path),
            limit=5
        )
        return [object.properties for object in response.objects]

    # def generate_with_text(self, query : str):
    #     return self.collection.generate.near_text(
    #         query=query,
    #         grouped_task="You are an helpful AI Assistant who explains the given text",
    #         filters=Filter.by_property("media_type").equal("text")
    #     )
    
    # def display_response(self, response):
    #     for object in response.objects:
    #         if object.properties['media_type'] == "text":
    #             print(object.properties)
    #             print('-'*20)
    #         elif object.properties['media_type'] == "image":
    #             print(object.properties)
    #             display(Image(object.properties['path']))
    #             print('-'*20)
    
    # def initiate_interaction(self):
    #     while True:
    #         print("-" * 20)
    #         choice = int(input("0 Exit, 1 Search with Text, 2 Search with Image, 3 Generate with Text : "))
    #         if choice == 0:
    #             print("Exiting")
    #             break
    #         elif choice == 1:
    #             query = input("Query : ")
    #             response = self.search_with_text(query)
    #             self.display_response(response)
    #         elif choice == 2:
    #             image_path = input("Image Path: ")
    #             response = self.search_with_image(image_path)
    #             self.display_response(response)
    #         elif choice == 3:
    #             query = input("Query : ")
    #             response = self.generate_with_text(query)
    #             print(response.generated)
    #             print("--SOURCE--")
    #             for object in response.objects:
    #                 print(object.properties)

    def close_connection(self):
        self.client.close()

# %%
folder_path = r"C:\Users\swast\OneDrive\Desktop\runSwastik\Localinsight\documents"
database = DatabaseClient(folder_path)

# %%
database.search_with_text(query="Cat")
# Out:
# [{'text': 'and cranny of their environment. Despite their reputation for being aloof, cats can be incredibly affectionate, forming strong bonds with their owners. Each cat has its own personality; some are',
#   'chunk_no': 4.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'},
#  {'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long captivated the hearts of humans. As one of the most popular pets worldwide, they offer a unique blend of independence and affection. From',
#   'media_type': 'text',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'chunk_no': 1.0},
#  {'text': 'Domesticated cats, or **Felis catus**, are known for their agility and grace. They have a natural curiosity that often leads them to explore every nook and cranny of their environment. Despite their',
#   'media_type': 'text',
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'chunk_no': 3.0},
#  {'text': 'Each cat has its own personality; some are playful and energetic, while others are calm and reserved.',
#   'chunk_no': 5.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'},
#  {'text': 'independent yet loving nature, combined with their graceful movements and expressive personalities, make cats one of the most beloved animals on the planet.',
#   'chunk_no': 14.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'}]

# %%
database.search_with_image(image_path=r"C:\Users\swast\OneDrive\Desktop\runSwastik\Localinsight\ignore\multimodal-workshop\2-multimodal\source\image\dog2.jpg")
# Out:
# [{'text': None,
#   'chunk_no': None,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\dog1.jpg',
#   'image': '...',
#   'media_type': 'image'},
#  {'text': None,
#   'chunk_no': None,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cat2.jpg',
#   'image': '...',
#   'media_type': 'image'},
#  {'text': None,
#   'chunk_no': None,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\meerkat1.jpg',
#   'image': '...',
#   'media_type': 'image'},
#  {'text': 'and eye behavior provide further clues to their mood.',
#   'chunk_no': 8.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'},
#  {'text': 'their feelings. A purring cat often indicates contentment, though it can also be a sign of nervousness or discomfort. Their tail movements, ear positions, and eye behavior provide further clues to',
#   'chunk_no': 7.0,
#   'path': 'C:\\Users\\swast\\OneDrive\\Desktop\\runSwastik\\Localinsight\\documents\\cats.txt',
#   'image': None,
#   'media_type': 'text'}]
