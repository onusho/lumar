# %%
import os
import io
import base64
import pandas as pd
import json
import xml.etree.ElementTree as ET
from docx import Document
import win32com.client as win32
import speech_recognition as sr
from moviepy.editor import VideoFileClip
from PIL import Image

from langchain_community.document_loaders import TextLoader, PyPDFLoader, UnstructuredPowerPointLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pprint import pprint

class DataLoader:
    def __init__(self, folder_path, chunk_size=100, chunk_overlap=10):
        self.folder_path = folder_path
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap

    def process_text_file(self, file_path):
        loader = TextLoader(file_path, encoding="utf-8")
        documents = loader.load()
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=self.chunk_size, chunk_overlap=self.chunk_overlap)
        chunks = text_splitter.split_documents(documents)
        return [
            {
                "chunk_no": int(idx),
                "text": chunk.page_content,
                "path": file_path,
                "file_type": "text",
                "media_type": "text"
            }
            for idx, chunk in enumerate(chunks)
        ]

    def process_pdf_file(self, file_path):
        loader = PyPDFLoader(file_path)
        documents = loader.load()
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=self.chunk_size, 
            chunk_overlap=self.chunk_overlap
            )
        chunks = text_splitter.split_documents(documents)
        return [
            {
                "chunk_no": int(idx),
                "text": chunk.page_content,
                "path": file_path,
                "file_type": "pdf",
                "media_type": "text"
            }
            for idx, chunk in enumerate(chunks)
        ]

    def process_pptx_file(self, file_path):
        loader = UnstructuredPowerPointLoader(file_path)
        documents = loader.load()
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=self.chunk_size, 
            chunk_overlap=self.chunk_overlap
            )
        chunks = text_splitter.split_documents(documents)
        return [
            {
                "chunk_no": int(idx),
                "text": chunk.page_content,
                "path": file_path,
                "file_type": "pptx",
                "media_type": "text"
            }
            for idx, chunk in enumerate(chunks)
        ]

    def process_xlsx_file(self, file_path):
        xls = pd.ExcelFile(file_path)
        chunked_documents = []
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(file_path, sheet_name=sheet_name)
            chunked_documents.append({
                "chunk_no": 1,
                "text": df.to_dict(),
                "path": file_path,
                "file_type": "table",
                "media_type": "text"
            })
        return chunked_documents

    def process_doc_file(self, file_path):
        try:
            word = win32.Dispatch("Word.Application")
            doc = word.Documents.Open(file_path)
            text = doc.Range().Text
            doc.Close(False)
            word.Quit()
            text_splitter = RecursiveCharacterTextSplitter(
                chunk_size=self.chunk_size, 
                chunk_overlap=self.chunk_overlap
                )
            chunks = text_splitter.split_text(text)
            return [
                {
                    "chunk_no": int(idx),
                    "text": chunk,
                    "path": file_path,
                    "file_type": "doc",
                    "media_type": "text"
                }
                for idx, chunk in enumerate(chunks)
            ]
        except Exception as e:
            print(f"Error processing DOC file {file_path}: {e}")
            return None

    def process_docx_file(self, file_path):
        try:
            doc = Document(file_path)
            text = '\n'.join([para.text for para in doc.paragraphs])
            text_splitter = RecursiveCharacterTextSplitter(
                separators=[" "], 
                chunk_size=self.chunk_size, 
                chunk_overlap=self.chunk_overlap
                )
            chunks = text_splitter.split_text(text)
            return [
                {
                    "chunk_no": int(idx),
                    "text": chunk,
                    "path": file_path,
                    "file_type": "docx",
                    "media_type": "text"
                }
                for idx, chunk in enumerate(chunks)
            ]
        except Exception as e:
            print(f"Error processing DOCX file {file_path}: {e}")
            return None

    def process_audio_file(self, file_path):
        recognizer = sr.Recognizer()
        try:
            with sr.AudioFile(file_path) as source:
                audio_data = recognizer.record(source)
                text = recognizer.recognize_google(audio_data)
            chunks = [text[i:i + self.chunk_size] for i in range(0, len(text), self.chunk_size)]

            return [
                {
                    "chunk_no": int(idx),
                    "text": chunk,
                    "path": file_path,
                    "file_type": "audio",
                    "media_type": "text"
                }
                for idx, chunk in enumerate(chunks)
            ]
        except Exception as e:
            print(f"Error processing audio file {file_path}: {e}")
            return None
        
    def process_image_file(self, file_path):
        try:
            with open(file_path, 'rb') as image_file:
                image_base64 = base64.b64encode(image_file.read()).decode('utf-8')
            return [{
                "path": file_path,
                "file_type": "image",
                "image": image_base64,
                "media_type": "image"
            }]
        except Exception as e:
            print(f"Error processing image file {file_path}: {e}")
            return None

    def process_csv_file(self, file_path):
        try:
            csv_data = pd.read_csv(file_path).to_string()
            return [{
                "chunk_no": 1,
                "text": csv_data,
                "path": file_path,
                "file_type": "csv",
                "media_type": "text"
            }]
        except Exception as e:
            print(f"Error processing CSV file {file_path}: {e}")
            return None
        
    def process_xml_file(self, file_path):
        try:
            tree = ET.parse(file_path)
            root = tree.getroot()
            xml_data = ET.tostring(root, encoding='unicode')
            return [{
                "chunk_no": 1,
                "text": xml_data,
                "path": file_path,
                "file_type": "xml",
                "media_type": "text"
            }]
        except Exception as e:
            print(f"Error processing XML file {file_path}: {e}")
            return None
        

    def process_json_file(self, file_path):
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                json_data = json.dumps(json.load(file), indent=4)
            return [{
                "chunk_no": 1,
                "text": json_data,
                "path": file_path,
                "file_type": "json",
                "media_type": "text"
            }]
        except Exception as e:
            print(f"Error processing JSON file {file_path}: {e}")
            return None

    def process_video_file(self, file_path, frame_interval=5, compression_quality=50, resize_factor=0.7):
        """
        Processes a video file to extract audio and frames.
        
        Parameters:
        - file_path (str): Path to the video file.
        - frame_interval (int): Interval in seconds between frames to extract.
        - compression_quality (int): Quality of the compressed image (1-100).
        - resize_factor (float): Scaling factor for resizing images (0 < resize_factor <= 1).

        Returns:
        - list: A list of dictionaries containing audio data and frame data.
        """
        video_data = []

        # Ensure frame_interval is greater than 0 to avoid division by zero
        if frame_interval <= 0:
            print(f"Error: frame_interval must be greater than 0. Received frame_interval={frame_interval}.")
            return video_data

        try:
            # Extracting audio
            video = VideoFileClip(file_path)
            audio_path = file_path.replace(os.path.splitext(file_path)[1], ".wav")
            
            try:
                video.audio.write_audiofile(audio_path)
                audio_data = self.process_audio_file(audio_path)
                if audio_data:
                    video_data.extend(audio_data)
            except Exception as e:
                print(f"Error processing audio file {audio_path}: {e}")

            # Extracting frames
            for i, frame in enumerate(video.iter_frames(fps=1.0 / frame_interval)):
                # Convert frame (numpy array) to PIL image
                pil_image = Image.fromarray(frame)
                
                # Resize the image if resize_factor is less than 1
                if resize_factor < 1.0:
                    new_size = (int(pil_image.width * resize_factor), int(pil_image.height * resize_factor))
                    pil_image = pil_image.resize(new_size, Image.LANCZOS)
                
                # Compress the image
                buffered = io.BytesIO()
                pil_image.save(buffered, format="JPEG", quality=compression_quality)
                
                # Convert to base64
                frame_base64 = base64.b64encode(buffered.getvalue()).decode('utf-8')
                
                # Add frame data to video_data list
                video_data.append({
                    "chunk_no": i,
                    "image": frame_base64,
                    "path": file_path,
                    "file_type": "video_frame",
                    "media_type": "image"
                })

        except Exception as e:
            print(f"Error processing video file {file_path}: {e}")
        
        return video_data


    def process_file(self, file_path):
        extension = os.path.splitext(file_path)[1].lower()
        if extension == '.txt':
            return self.process_text_file(file_path)
        elif extension == '.pdf':
            return self.process_pdf_file(file_path)
        elif extension == '.pptx':
            return self.process_pptx_file(file_path)
        elif extension == '.xlsx':
            return self.process_xlsx_file(file_path)
        elif extension == '.doc':
            return self.process_doc_file(file_path)
        elif extension == '.docx':
            return self.process_docx_file(file_path)
        elif extension in ['.wav', '.mp3']:
            return self.process_audio_file(file_path)
        elif extension in ['.png', '.jpg', '.jpeg', '.bmp', '.gif']:
            return self.process_image_file(file_path)
        elif extension in ['.mp4', '.avi', '.mov', '.wmv']:
            return self.process_video_file(file_path)
        elif extension == '.csv':
            return self.process_csv_file(file_path)
        elif extension == '.xml':
            return self.process_xml_file(file_path)
        elif extension == '.json':
            return self.process_json_file(file_path)
        else:
            return None

    def load_data(self):
        all_data = []
        for root, dirs, files in os.walk(self.folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                processed_data = self.process_file(file_path)
                if processed_data is not None:
                    all_data.extend(processed_data)
        return all_data

if __name__ == "__main__":
    folder_path = r"C:\Users\Anush\Desktop\Christ\Specialization Project\Localinsight\documents"
    loader = DataLoader(folder_path)
    data = loader.load_data()
    pprint(data)
# Out:
# MoviePy - Writing audio in C:\Users\Anush\Desktop\Christ\Specialization Project\Localinsight\documents\sample-video.wav
# MoviePy - Done.
# Error processing audio file C:\Users\Anush\Desktop\Christ\Specialization Project\Localinsight\documents\sample-video.wav:
# Error processing audio file C:\Users\Anush\Desktop\Christ\Specialization Project\Localinsight\documents\sample-video.wav:
# [{'chunk_no': 0,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Alice was beginning to get very tired of sitting by her sister on '
#           'the bank, and of having nothing to'},
#  {'chunk_no': 1,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'to do: once or twice she had peeped into the book her sister was '
#           'reading, but it had no pictures or'},
#  {'chunk_no': 2,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'or conversations in it, “and what is the use of a book,” thought '
#           'Alice “without pictures or'},
#  {'chunk_no': 3,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'or conversations?”'},
#  {'chunk_no': 4,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'So she was considering in her own mind (as well as she could, for '
#           'the hot day made her feel very'},
#  {'chunk_no': 5,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'feel very sleepy and stupid), whether the pleasure of making a '
#           'daisy-chain would be worth the'},
#  {'chunk_no': 6,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'worth the trouble of getting up and picking the daisies, when '
#           'suddenly a White Rabbit with pink'},
#  {'chunk_no': 7,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'with pink eyes ran close by her.'},
#  {'chunk_no': 8,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'There was nothing so very remarkable in that; nor did Alice think '
#           'it so very much out of the way to'},
#  {'chunk_no': 9,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'way to hear the Rabbit say to itself, “Oh dear! Oh dear! I shall be '
#           'late!” (when she thought it'},
#  {'chunk_no': 10,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'it over afterwards, it occurred to her that she ought to have '
#           'wondered at this, but at the time it'},
#  {'chunk_no': 11,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'time it all seemed quite natural); but when the Rabbit actually '
#           'took a watch out of its'},
#  {'chunk_no': 12,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'of its waistcoat-pocket, and looked at it, and then hurried on, '
#           'Alice started to her feet, for it'},
#  {'chunk_no': 13,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'for it flashed across her mind that she had never before seen a '
#           'rabbit with either a'},
#  {'chunk_no': 14,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'either a waistcoat-pocket, or a watch to take out of it, and '
#           'burning with curiosity, she ran across'},
#  {'chunk_no': 15,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'across the field after it, and fortunately was just in time to see '
#           'it pop down a large rabbit-hole'},
#  {'chunk_no': 16,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'under the hedge.'},
#  {'chunk_no': 17,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'In another moment down went Alice after it, never once considering '
#           'how in the world she was to get'},
#  {'chunk_no': 18,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'to get out again.'},
#  {'chunk_no': 19,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'The rabbit-hole went straight on like a tunnel for some way, and '
#           'then dipped suddenly down, so'},
#  {'chunk_no': 20,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'down, so suddenly that Alice had not a moment to think about '
#           'stopping herself before she found'},
#  {'chunk_no': 21,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'she found herself falling down a very deep well.'},
#  {'chunk_no': 22,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Either the well was very deep, or she fell very slowly, for she had '
#           'plenty of time as she went down'},
#  {'chunk_no': 23,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'went down to look about her and to wonder what was going to happen '
#           'next. First, she tried to look'},
#  {'chunk_no': 24,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'to look down and make out what she was coming to, but it was too '
#           'dark to see anything; then she'},
#  {'chunk_no': 25,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'then she looked at the sides of the well, and noticed that they '
#           'were filled with cupboards and'},
#  {'chunk_no': 26,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'and book-shelves; here and there she saw maps and pictures hung '
#           'upon pegs. She took down a jar from'},
#  {'chunk_no': 27,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'jar from one of the shelves as she passed; it was labelled “ORANGE '
#           'MARMALADE”, but to her great'},
#  {'chunk_no': 28,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'her great disappointment it was empty: she did not like to drop the '
#           'jar for fear of killing'},
#  {'chunk_no': 29,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'killing somebody underneath, so managed to put it into one of the '
#           'cupboards as she fell past it.'},
#  {'chunk_no': 30,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': '“Well!” thought Alice to herself, “after such a fall as this, I '
#           'shall think nothing of tumbling'},
#  {'chunk_no': 31,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'tumbling down stairs! How brave they’ll all think me at home! Why, '
#           'I wouldn’t say anything about'},
#  {'chunk_no': 32,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'about it, even if I fell off the top of the house!” (Which was very '
#           'likely true.)'},
#  {'chunk_no': 33,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Down, down, down. Would the fall never come to an end? “I wonder '
#           'how many miles I’ve fallen by this'},
#  {'chunk_no': 34,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'by this time?” she said aloud. “I must be getting somewhere near '
#           'the centre of the earth. Let me'},
#  {'chunk_no': 35,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Let me see: that would be four thousand miles down, I think—” (for, '
#           'you see, Alice had learnt'},
#  {'chunk_no': 36,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'learnt several things of this sort in her lessons in the '
#           'schoolroom, and though this was not a very'},
#  {'chunk_no': 37,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'a very good opportunity for showing off her knowledge, as there was '
#           'no one to listen to her, still'},
#  {'chunk_no': 38,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'still it was good practice to say it over) “—yes, that’s about the '
#           'right distance—but then I wonder'},
#  {'chunk_no': 39,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'I wonder what Latitude or Longitude I’ve got to?” (Alice had no '
#           'idea what Latitude was, or'},
#  {'chunk_no': 40,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'was, or Longitude either, but thought they were nice grand words to '
#           'say.)'},
#  {'chunk_no': 41,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Presently she began again. “I wonder if I shall fall right through '
#           'the earth! How funny it’ll seem'},
#  {'chunk_no': 42,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'seem to come out among the people that walk with their heads '
#           'downward! The Antipathies, I think—”'},
#  {'chunk_no': 43,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'I think—” (she was rather glad there was no one listening, this '
#           'time, as it didn’t sound at all the'},
#  {'chunk_no': 44,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'all the right word) “—but I shall have to ask them what the name of '
#           'the country is, you know.'},
#  {'chunk_no': 45,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'you know. Please, Ma’am, is this New Zealand or Australia?” (and '
#           'she tried to curtsey as she'},
#  {'chunk_no': 46,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'as she spoke—fancy curtseying as you’re falling through the air! Do '
#           'you think you could manage it?)'},
#  {'chunk_no': 47,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'it?) “And what an ignorant little girl she’ll think me for asking! '
#           'No, it’ll never do to ask:'},
#  {'chunk_no': 48,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'to ask: perhaps I shall see it written up somewhere.”'},
#  {'chunk_no': 49,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Down, down, down. There was nothing else to do, so Alice soon began '
#           'talking again. “Dinah’ll miss'},
#  {'chunk_no': 50,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'miss me very much to-night, I should think!” (Dinah was the cat.) '
#           '“I hope they’ll remember her'},
#  {'chunk_no': 51,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'her saucer of milk at tea-time. Dinah my dear! I wish you were down '
#           'here with me! There are no mice'},
#  {'chunk_no': 52,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'no mice in the air, I’m afraid, but you might catch a bat, and '
#           'that’s very like a mouse, you know.'},
#  {'chunk_no': 53,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'you know. But do cats eat bats, I wonder?” And here Alice began to '
#           'get rather sleepy, and went on'},
#  {'chunk_no': 54,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'went on saying to herself, in a dreamy sort of way, “Do cats eat '
#           'bats? Do cats eat bats?” and'},
#  {'chunk_no': 55,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'and sometimes, “Do bats eat cats?” for, you see, as she couldn’t '
#           'answer either question, it didn’t'},
#  {'chunk_no': 56,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'it didn’t much matter which way she put it. She felt that she was '
#           'dozing off, and had just begun to'},
#  {'chunk_no': 57,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'begun to dream that she was walking hand in hand with Dinah, and '
#           'saying to her very earnestly,'},
#  {'chunk_no': 58,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': '“Now, Dinah, tell me the truth: did you ever eat a bat?” when '
#           'suddenly, thump! thump! down she came'},
#  {'chunk_no': 59,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'she came upon a heap of sticks and dry leaves, and the fall was '
#           'over.'},
#  {'chunk_no': 60,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Alice was not a bit hurt, and she jumped up on to her feet in a '
#           'moment: she looked up, but it was'},
#  {'chunk_no': 61,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'it was all dark overhead; before her was another long passage, and '
#           'the White Rabbit was still in'},
#  {'chunk_no': 62,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'still in sight, hurrying down it. There was not a moment to be '
#           'lost: away went Alice like the wind,'},
#  {'chunk_no': 63,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'the wind, and was just in time to hear it say, as it turned a '
#           'corner, “Oh my ears and whiskers, how'},
#  {'chunk_no': 64,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'how late it’s getting!” She was close behind it when she turned the '
#           'corner, but the Rabbit was no'},
#  {'chunk_no': 65,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'was no longer to be seen: she found herself in a long, low hall, '
#           'which was lit up by a row of lamps'},
#  {'chunk_no': 66,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'of lamps hanging from the roof.'},
#  {'chunk_no': 67,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'There were doors all round the hall, but they were all locked; and '
#           'when Alice had been all the way'},
#  {'chunk_no': 68,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'the way down one side and up the other, trying every door, she '
#           'walked sadly down the middle,'},
#  {'chunk_no': 69,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'middle, wondering how she was ever to get out again.'},
#  {'chunk_no': 70,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Suddenly she came upon a little three-legged table, all made of '
#           'solid glass; there was nothing on'},
#  {'chunk_no': 71,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'on it except a tiny golden key, and Alice’s first thought was that '
#           'it might belong to one of the'},
#  {'chunk_no': 72,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'of the doors of the hall; but, alas! either the locks were too '
#           'large, or the key was too small, but'},
#  {'chunk_no': 73,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'but at any rate it would not open any of them. However, on the '
#           'second time round, she came upon a'},
#  {'chunk_no': 74,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'upon a low curtain she had not noticed before, and behind it was a '
#           'little door about fifteen inches'},
#  {'chunk_no': 75,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'inches high: she tried the little golden key in the lock, and to '
#           'her great delight it fitted!'},
#  {'chunk_no': 76,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'Alice opened the door and found that it led into a small passage, '
#           'not much larger than a rat-hole:'},
#  {'chunk_no': 77,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'rat-hole: she knelt down and looked along the passage into the '
#           'loveliest garden you ever saw. How'},
#  {'chunk_no': 78,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'saw. How she longed to get out of that dark hall, and wander about '
#           'among those beds of bright'},
#  {'chunk_no': 79,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'of bright flowers and those cool fountains, but she could not even '
#           'get her head through the'},
#  {'chunk_no': 80,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'the doorway; “and even if my head would go through,” thought poor '
#           'Alice, “it would be of very'},
#  {'chunk_no': 81,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'of very little use without my shoulders. Oh, how I wish I could '
#           'shut up like a telescope! I think I'},
#  {'chunk_no': 82,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'I think I could, if I only knew how to begin.” For, you see, so '
#           'many out-of-the-way things had'},
#  {'chunk_no': 83,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'had happened lately, that Alice had begun to think that very few '
#           'things indeed were really'},
#  {'chunk_no': 84,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'really impossible.'},
#  {'chunk_no': 85,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'There seemed to be no use in waiting by the little door, so she '
#           'went back to the table, half hoping'},
#  {'chunk_no': 86,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'hoping she might find another key on it, or at any rate a book of '
#           'rules for shutting people up like'},
#  {'chunk_no': 87,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'up like telescopes: this time she found a little bottle on it, '
#           '(“which certainly was not here'},
#  {'chunk_no': 88,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'not here before,” said Alice,) and round the neck of the bottle was '
#           'a paper label, with the words'},
#  {'chunk_no': 89,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'the words “DRINK ME,” beautifully printed on it in large letters.'},
#  {'chunk_no': 90,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'It was all very well to say “Drink me,” but the wise little Alice '
#           'was not going to do that in a'},
#  {'chunk_no': 91,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'that in a hurry. “No, I’ll look first,” she said, “and see whether '
#           'it’s marked ‘poison’ or not”;'},
#  {'chunk_no': 92,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'or not”; for she had read several nice little histories about '
#           'children who had got burnt, and eaten'},
#  {'chunk_no': 93,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'and eaten up by wild beasts and other unpleasant things, all '
#           'because they would not remember the'},
#  {'chunk_no': 94,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'the simple rules their friends had taught them: such as, that a '
#           'red-hot poker will burn you if you'},
#  {'chunk_no': 95,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'if you hold it too long; and that if you cut your finger very '
#           'deeply with a knife, it usually'},
#  {'chunk_no': 96,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'usually bleeds; and she had never forgotten that, if you drink much '
#           'from a bottle marked “poison,”'},
#  {'chunk_no': 97,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': '“poison,” it is almost certain to disagree with you, sooner or '
#           'later.'},
#  {'chunk_no': 98,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'However, this bottle was not marked “poison,” so Alice ventured to '
#           'taste it, and finding it very'},
#  {'chunk_no': 99,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'it very nice, (it had, in fact, a sort of mixed flavour of '
#           'cherry-tart, custard, pine-apple, roast'},
#  {'chunk_no': 100,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\alice.txt',
#   'text': 'roast turkey, toffee, and hot buttered toast,) she very soon '
#           'finished it off.'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cat1.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cat2.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cat3.jpg'},
#  {'chunk_no': 0,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': "Here's a sample text about cats:\n"
#           '\n'
#           '---\n'
#           '\n'
#           '**The Enigmatic World of Cats**'},
#  {'chunk_no': 1,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'Cats, with their sleek bodies and mesmerizing eyes, have long '
#           'captivated the hearts of humans. As'},
#  {'chunk_no': 2,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'As one of the most popular pets worldwide, they offer a unique '
#           'blend of independence and affection.'},
#  {'chunk_no': 3,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'From the domesticated house cats to the wild, majestic lions, cats '
#           'belong to a family known as'},
#  {'chunk_no': 4,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'known as Felidae.'},
#  {'chunk_no': 5,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'Domesticated cats, or **Felis catus**, are known for their agility '
#           'and grace. They have a natural'},
#  {'chunk_no': 6,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'a natural curiosity that often leads them to explore every nook and '
#           'cranny of their environment.'},
#  {'chunk_no': 7,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'Despite their reputation for being aloof, cats can be incredibly '
#           'affectionate, forming strong bonds'},
#  {'chunk_no': 8,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'bonds with their owners. Each cat has its own personality; some are '
#           'playful and energetic, while'},
#  {'chunk_no': 9,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'while others are calm and reserved.'},
#  {'chunk_no': 10,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'One of the most fascinating aspects of cats is their communication. '
#           'Cats use a variety of'},
#  {'chunk_no': 11,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'of vocalizations, body language, and even scent markings to convey '
#           'their feelings. A purring cat'},
#  {'chunk_no': 12,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'cat often indicates contentment, though it can also be a sign of '
#           'nervousness or discomfort. Their'},
#  {'chunk_no': 13,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'Their tail movements, ear positions, and eye behavior provide '
#           'further clues to their mood.'},
#  {'chunk_no': 14,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'Cats are also skilled hunters, a trait inherited from their wild '
#           'ancestors. Even the most pampered'},
#  {'chunk_no': 15,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'pampered house cat might display hunting behavior, like stalking '
#           'and pouncing on toys or insects.'},
#  {'chunk_no': 16,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'insects. This instinctual behavior is a reminder of their wild '
#           'roots.'},
#  {'chunk_no': 17,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'In addition to their captivating behavior, cats have a rich history '
#           'with humans. They were revered'},
#  {'chunk_no': 18,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'revered in ancient Egypt, where they were considered sacred and '
#           'often depicted in art and statues.'},
#  {'chunk_no': 19,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'statues. Today, cats continue to play important roles in various '
#           'cultures and households, offering'},
#  {'chunk_no': 20,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'offering companionship and, at times, a sense of mystery.'},
#  {'chunk_no': 21,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': "Whether you're a long-time cat lover or a newcomer to the feline "
#           "world, there's always something"},
#  {'chunk_no': 22,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'something new to discover about these intriguing creatures. Their '
#           'independent yet loving nature,'},
#  {'chunk_no': 23,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'nature, combined with their graceful movements and expressive '
#           'personalities, make cats one of the'},
#  {'chunk_no': 24,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'of the most beloved animals on the planet.'},
#  {'chunk_no': 25,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': '---'},
#  {'chunk_no': 26,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'This text offers a brief exploration of the fascinating world of '
#           'cats, touching on their behavior,'},
#  {'chunk_no': 27,
#   'file_type': 'text',
#   'media_type': 'text',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\cats.txt',
#   'text': 'behavior, communication, and historical significance.'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\dog1.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\dog2.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\dog3.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\meerkat1.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\meerkat2.jpg'},
#  {'file_type': 'image',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\meerkat3.jpg'},
#  {'chunk_no': 0,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 1,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 2,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 3,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 4,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 5,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 6,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'},
#  {'chunk_no': 7,
#   'file_type': 'video_frame',
#   'image': '...',
#   'media_type': 'image',
#   'path': 'C:\\Users\\Anush\\Desktop\\Christ\\Specialization '
#           'Project\\Localinsight\\documents\\sample-video.mp4'}]
